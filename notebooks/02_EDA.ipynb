# %%
import os
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# 'c:\\Users\\karthikeya\\New_Delhi_Reviews\\notebooks'

# %%
os.chdir('..')

# %%
from src.components.data_ingestion import DataIngestionConfig

# %%
df = pd.read_csv(DataIngestionConfig.train_data_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103306 entries, 0 to 103305
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   rating_review  103306 non-null  int64
#  1   review_full    103304 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(axis=0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103304 entries, 0 to 103305
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   rating_review  103304 non-null  int64
#  1   review_full    103304 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt

plt.hist(x=df['review_full'].str.len());
plt.xticks(ticks=np.arange(0, 8000, 500), rotation=90);  # Rotate x-ticks by 45 degrees;

# %%
plt.hist(x=df['review_full'].dropna().str.split().map(lambda X : len(X)));
plt.xticks(ticks=np.arange(0,800,40),rotation=90);

# %%
plt.figure(figsize=(12, 8))
sns.histplot(
    x=df['review_full'].dropna().str.split().map(lambda X: len(X)),
    kde=True,
    hue=df['rating_review'],
    palette='rainbow'  # Apply the rainbow colormap
)

# Customize xticks
plt.xticks(ticks=range(0, 800, 25), rotation=90)  # Adjust the range and step size as needed
plt.show()

# %% [markdown]
# ## Most of the reveiws have words ranging from 25 to 50
